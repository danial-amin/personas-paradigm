# %%
# !pip install anthropic pandas
# Out:
# Collecting anthropic
#   Downloading anthropic-0.86.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading anthropic-0.86.0-py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.4/469.4 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.86.0

# %% [markdown]
# Creating the Data into a String format

# %%
# ── Block 1: Data preparation ─────────────────────────────────────────────────
import pandas as pd
import json

# Load your dataset (replace with your actual file)
df = pd.read_csv("/data/HCI_2025_DigitalLifeSurvey_public.csv")

# --- Helper functions ---
def dataframe_to_sample(df, max_rows=1000):
    """Return a readable string of the first N rows."""
    return df.head(max_rows).to_string(index=False)

def aggregate_stats(df):
    """Summary statistics so the LLM understands distributions."""
    stats = {}
    for col in df.select_dtypes(include='number').columns:
        stats[col] = {
            "mean": round(df[col].mean(), 2),
            "min":  df[col].min(),
            "max":  df[col].max()
        }
    for col in df.select_dtypes(include='object').columns:
        stats[col] = df[col].value_counts().head(5).to_dict()
    return json.dumps(stats, indent=2)

# Build the data payload (reused in Block 2)
data_sample = dataframe_to_sample(df)
data_stats  = aggregate_stats(df)
total_rows  = len(df)

print(f"✅ Dataset ready: {total_rows} rows, {len(df.columns)} columns")
print(df.head(3))
# Out:
# ✅ Dataset ready: 1003 rows, 45 columns
#   Do you consent to participate in this study? Column 3 What is your gender?  \
# 0                               Yes, i consent  45 - 54               Female
# 1                               Yes, i consent  45 - 54               Female
# 2                               Yes, i consent  25 - 34                 Male
#
#   What best describes your primary daily activity?  \
# 0                                             Work
# 1                                             Work
# 2                                             Work
#
#   Which country/region do  live in?  \
# 0                               USA
# 1     United Kingdom, West Midlands
# 2                               USA
#
#   On average, how many hours do you spend online each day? (self-estimate)  \
# 0                                       9 - 10 hours
# 1                                        7 - 8 hours
# 2                                  Less than 2 hours
#
#   On days when you spend more than 4 hours online, how would you describe your energy afterward?  \
# 0                                            Neutral
# 1                                            Neutral
# 2                                              Tired
#
#   What's one word that best describes how you feel after long periods online?  \
# 0                                              Tired
# 1                                               calm
# 2                                            Drained
#
#   What's one word that describes a positive feeling you get from being online?  \
# 0                                           Informed
# 1                                            engaged
# 2                                             Active
#
#   What’s one word that best describes how you feel after regretting time spent online?   \
# 0                                           Saddened
# 1                                           listless
# 2                                              Guilt
#
#    ...                 Completed at Reviewed at                  Archived at  \
# 0  ...  2025-09-09T22:07:37.368000Z         NaN  2025-09-09T22:07:37.769223Z
# 1  ...  2025-09-09T22:07:56.940000Z         NaN  2025-09-09T22:07:57.327857Z
# 2  ...  2025-09-09T22:08:38.086000Z         NaN  2025-09-09T22:08:38.495280Z
#
#   Age     Sex Ethnicity simplified Country of residence     Nationality  \
# 0  53  Female                Black        United States   United States
# 1  54  Female                White       United Kingdom  United Kingdom
# 2  26    Male                White        United States   United States
#
#   Language Employment status
# 0  English      DATA_EXPIRED
# 1  English         Part-Time
# 2  English         Full-Time
#
# [3 rows x 45 columns]

# %% [markdown]
# ## Generating the Personas

# %% [markdown]
# ### Goal Driven Personas

# %%
# ── Block 2: Load prompt and generate personas (JSON output) ──────────────────
import anthropic
import json
from google.colab import userdata

# --- Config ---
PRODUCT     = "a company offering digital life coaching services"
MODEL       = "claude-sonnet-4-6"
PROMPT_FILE = "prompts/goal-driven-persona-prompt.txt"

# --- Client ---
client = anthropic.Anthropic(api_key="")

# --- Load prompt template ---
with open(PROMPT_FILE, "r") as f:
    prompt_template = f.read()

system_prompt = prompt_template.replace("[PRODUCT]", PRODUCT)

# --- Build user message ---
user_message = f"""Here is the dataset ({total_rows} rows total):

--- DATA SAMPLE ---
{data_sample}

--- SUMMARY STATISTICS ---
{data_stats}

Using the data above, generate the personas now.
"""

# --- Call the API ---
response = client.messages.create(
    model=MODEL,
    max_tokens=4096,
    system=system_prompt,
    messages=[
        {"role": "user", "content": user_message}
    ]
)

personas_output = response.content[0].text

with open("outputs/personas_output_goal_oriented.txt", "w") as f:
    f.write(personas_output)

print("Saved to personas_output_goal_oriented.txt ✓")
# Out:
# Saved to personas_output.txt ✓

# %% [markdown]
# Engaging Personas

# %%
# --- Config ---
PRODUCT     = "a company offering digital life coaching services"
PRODUCT_DOMAIN="personal development and digital wellness"
MODEL       = "claude-sonnet-4-6"
PROMPT_FILE = "/prompts/engaging-persona-prompt.txt"

# --- Client ---
client = anthropic.Anthropic(api_key="")

# --- Load prompt template ---
with open(PROMPT_FILE, "r") as f:
    prompt_template = f.read()

system_prompt = (prompt_template
    .replace("[PRODUCT]",        PRODUCT)
    .replace("[PRODUCT DOMAIN]", PRODUCT_DOMAIN))

# --- Build user message ---
user_message = f"""Here is the dataset ({total_rows} rows total):

--- DATA SAMPLE ---
{data_sample}

--- SUMMARY STATISTICS ---
{data_stats}

Using the data above, generate the personas now.
"""

# --- Call the API ---
response = client.messages.create(
    model=MODEL,
    max_tokens=4096,
    system=system_prompt,
    messages=[
        {"role": "user", "content": user_message}
    ]
)

personas_output = response.content[0].text

with open("outputs/personas_output_engaging.txt", "w") as f:
    f.write(personas_output)

print("Saved to personas_output.txt ✓")
# Out:
# Saved to personas_output.txt ✓

# %% [markdown]
# Role Based Personas

# %%
# --- Config ---
PRODUCT     = "a company offering digital life coaching services"
MODEL       = "claude-sonnet-4-6"
PROMPT_FILE = "/prompts/role-based-persona-prompt.txt"

# --- Client ---
client = anthropic.Anthropic(api_key="")

# --- Load prompt template ---
with open(PROMPT_FILE, "r") as f:
    prompt_template = f.read()

system_prompt = prompt_template.replace("[PRODUCT]", PRODUCT)

# --- Build user message ---
user_message = f"""Here is the dataset ({total_rows} rows total):

--- DATA SAMPLE ---
{data_sample}

--- SUMMARY STATISTICS ---
{data_stats}

Using the data above, generate the personas now.
"""

# --- Call the API ---
response = client.messages.create(
    model=MODEL,
    max_tokens=4096,
    system=system_prompt,
    messages=[
        {"role": "user", "content": user_message}
    ]
)

personas_output = response.content[0].text

with open("outputs/personas_output_role_based.txt", "w") as f:
    f.write(personas_output)

print("Saved to personas_output_role_based.txt ✓")
# Out:
# Saved to personas_output_role_based.txt ✓

# %% [markdown]
# Extreme Personas

# %%
# --- Config ---
PRODUCT     = "a company offering digital life coaching services"
MODEL       = "claude-sonnet-4-6"
PROMPT_FILE = "/prompts/extreme-persona-prompt.txt"

# --- Client ---
client = anthropic.Anthropic(api_key="")

# --- Load prompt template ---
with open(PROMPT_FILE, "r") as f:
    prompt_template = f.read()

system_prompt = prompt_template.replace("[PRODUCT]", PRODUCT)

# --- Build user message ---
user_message = f"""Here is the dataset ({total_rows} rows total):

--- DATA SAMPLE ---
{data_sample}

--- SUMMARY STATISTICS ---
{data_stats}

Using the data above, generate the personas now.
"""

# --- Call the API ---
response = client.messages.create(
    model=MODEL,
    max_tokens=4096,
    system=system_prompt,
    messages=[
        {"role": "user", "content": user_message}
    ]
)

personas_output = response.content[0].text

with open("outputs/personas_output_extreme.txt", "w") as f:
    f.write(personas_output)

print("Saved to personas_output_extreme.txt ✓")
# Out:
# Saved to personas_output_extreme.txt ✓

# %% [markdown]
# Proto Persona Prompt

# %%
# --- Config ---
PRODUCT     = "a company offering digital life coaching services"
MODEL       = "claude-sonnet-4-6"
PROMPT_FILE = "/prompts/proto-prompt.txt"

# --- Client ---
client = anthropic.Anthropic(api_key="")

# --- Load prompt template ---
with open(PROMPT_FILE, "r") as f:
    prompt_template = f.read()

system_prompt = prompt_template.replace("[PRODUCT]", PRODUCT)


# --- Call the API ---
response = client.messages.create(
    model=MODEL,
    max_tokens=4096,
    system=system_prompt,
    messages=[
        {"role": "user", "content": "Generate the proto-personas now."}
    ]
)

personas_output = response.content[0].text

with open("outputs/personas_output_proto.txt", "w") as f:
    f.write(personas_output)

print("Saved to personas_output_proto.txt ✓")
# Out:
# Saved to personas_output_proto.txt ✓

# %% [markdown]
# Saving everything

# %%
import zipfile, os

with zipfile.ZipFile('project.zip', 'w', zipfile.ZIP_DEFLATED) as zf:
    for root, dirs, filenames in os.walk('.'):
        for f in filenames:
            filepath = os.path.join(root, f)
            if 'sample_data' not in filepath:
                zf.write(filepath)
